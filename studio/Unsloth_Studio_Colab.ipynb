# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1056, done.
# remote: Counting objects: 100% (1056/1056), done.
# remote: Compressing objects: 100% (881/881), done.
# remote: Total 1056 (delta 174), reused 682 (delta 155), pack-reused 0 (from 0)
# Receiving objects: 100% (1056/1056), 31.26 MiB | 37.61 MiB/s, done.
# Resolving deltas: 100% (174/174), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  upgrading npm...
#   node           v20.19.0 | npm 11.12.1
#                  installing bun...
#                  bun installed (1.3.11)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [====================] 11/11  finalizing
#   deps           installed
#   transformers   5.x pre-installed
#   llama.cpp      failed to resolve a published llama.cpp release via ggml-org/llama.cpp
#                  llama.cpp diagnostics (last 120 lines):
#    | [llama-prebuilt] fatal helper error: HTTP Error 422: Unprocessable Entity
#                  resolved llama.cpp tag: b8642
#                  installing prebuilt llama.cpp...
#                  prebuilt tag resolution failed -- falling back to source build
#                  building (CUDA, sm_75)...

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
